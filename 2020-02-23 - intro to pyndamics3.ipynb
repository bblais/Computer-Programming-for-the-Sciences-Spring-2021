# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from pyndamics3 import Simulation
# Out:
# pyndamics3  version  0.0.3

# %% [markdown]
# $$
# \frac{dp}{dt} = a\cdot p
# $$
#
# $$
# \dot{p} = a\cdot p
# $$

# %% [markdown]
# $$
# p' = a\cdot p
# $$

# %%
sim=Simulation()
sim.figsize=(5,3)
sim.add(" p'=a*p ",2,plot=True)  # initial condition for p. what is p at t=0?
sim.params(a=.5)
sim.run(10)  # run for the specified time

# %%
sim=Simulation()
sim.figsize=(5,3)
sim.add(" p'=a*p ",2,plot=True)  # initial condition for p. what is p at t=0?
sim.add(" p2'=a2*p2 ",2)  # initial condition for p. what is p at t=0?
sim.params(a=0.5,a2=1)
sim.run(10)  # run for the specified time,

# %%
sim=Simulation()
sim.figsize=(5,3)
sim.add(" p'=a*p ",2,plot=1)  # initial condition for p. what is p at t=0?
sim.add(" p2'=a2*p2 ",2,plot=1)  # initial condition for p. what is p at t=0?
sim.params(a=0.5,a2=.6)
sim.run(10)  # run for the specified time,

# %% [markdown]
# $$
# \frac{dx}{dt} = v
# $$
#
# $$
# \frac{dv}{dt}=g-k\cdot v^2/m
# $$

# %% [markdown]
# Fixed point for $v$?
#
#
# $$
# \frac{dv}{dt}=0
# $$

# %% [markdown]
# $$
# v = \sqrt{mg/k}
# $$

# %%
sim=Simulation()
sim.figsize=(5,3)

sim.add("x'=v",0,plot=True)
sim.add("v'=g-k*v**2/m",0,plot=True)
sim.params(g=10,k=1,m=5)

sim.run(10)  # run for the specified time,

# %%
sim.v[-10:]
# Out:
# array([4.47213596, 4.47213596, 4.47213596, 4.47213596, 4.47213596,
#        4.47213596, 4.47213596, 4.47213596, 4.47213596, 4.47213596])

# %%
sim=Simulation()
sim.figsize=(5,3)

sim.add("x'=v",0,plot=False)
sim.add("v'=g-k*v**2/m",0,plot=True)
sim.params(g=10,k=0.1,m=5)

sim.run(10)  # run for the specified time,
