# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from pyndamics3 import Simulation
# Out:
# pyndamics3  version  0.0.6

# %%
t=array([7,14,21,28,35,42,49,56,63,70,77,84],float)
h=array([17.93,36.36,67.76,98.10,131,169.5,205.5,228.3,247.1,250.5,253.8,254.5])

# %%
plot(t,h,'o')

# %% [markdown]
# https://lmfit.github.io/lmfit-py/

# %%
from lmfit import *

# %%
model=models.LinearModel()

# %%
model.param_names
# Out:
# ['slope', 'intercept']

# %%
model2=models.GaussianModel()

# %%
model2.param_names
# Out:
# ['amplitude', 'center', 'sigma']

# %%
results=model.fit(h,x=t,slope=1,intercept=5)
results
# Out:
# <h2> Model</h2> Model(linear) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>7</td><td></td></tr><tr><td># data points</td><td>12</td><td></td></tr><tr><td># variables</td><td>2</td><td></td></tr><tr><td>chi-square</td><td> 5339.27222</td><td></td></tr><tr><td>reduced chi-square</td><td> 533.927222</td><td></td></tr><tr><td>Akaike info crit.</td><td> 77.1752558</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 78.1450691</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> slope </td><td>  3.45220280 </td><td>  0.27604187 </td><td> (8.00%) </td><td> 1 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> intercept </td><td>  6.28727273 </td><td>  14.2212932 </td><td> (226.19%) </td><td> 5 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>slope</td><td>intercept</td><td>-0.8832</td></tr></table>

# %%
x_fake=linspace(0,90,100)
y_fake=results.eval(x=x_fake)
plot(t,h,'o')
plot(x_fake,y_fake,'-')

# %% [markdown]
# https://lmfit.github.io/lmfit-py/builtin_models.html?highlight=models#module-lmfit.models

# %%
model=models.StepModel(form='logistic')
results=model.fit(h,x=t,amplitude=300,center=40,sigma=1)
results
# Out:
# <h2> Model</h2> Model(step, form='logistic') <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>29</td><td></td></tr><tr><td># data points</td><td>12</td><td></td></tr><tr><td># variables</td><td>3</td><td></td></tr><tr><td>chi-square</td><td> 127.064780</td><td></td></tr><tr><td>reduced chi-square</td><td> 14.1183088</td><td></td></tr><tr><td>Akaike info crit.</td><td> 34.3174846</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 35.7722045</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> amplitude </td><td>  261.039642 </td><td>  2.63598527 </td><td> (1.01%) </td><td> 300 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> center </td><td>  34.2733853 </td><td>  0.45938039 </td><td> (1.34%) </td><td> 40 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> sigma </td><td>  11.4015675 </td><td>  0.39097754 </td><td> (3.43%) </td><td> 1 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>amplitude</td><td>center</td><td>0.7239</td></tr><tr><td>amplitude</td><td>sigma</td><td>0.6645</td></tr><tr><td>center</td><td>sigma</td><td>0.4645</td></tr></table>

# %%
model.param_names
# Out:
# ['amplitude', 'center', 'sigma']

# %%
x_fake=linspace(0,90,100)
y_fake=results.eval(x=x_fake)
plot(t,h,'o')
plot(x_fake,y_fake,'-')
